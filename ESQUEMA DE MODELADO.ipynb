# %% [markdown]
# # Estudio de la tipologia de conductores de vehículos eléctricos segun parametros de comportamiento
#
#
#
# Fecha: 28/11/2024
# ### Participantes
# - Jose Manuel Villa Romero
# - Sebastian Vasquez Grajales
#
#
# **Contexto**
# >
# Este conjunto de datos proporciona un análisis exhaustivo de los patrones de carga de vehículos eléctricos (EV) y el comportamiento de los usuarios. Contiene 1320 muestras de datos de sesiones de carga, incluidas métricas como el consumo de energía, la duración de la carga y los detalles del vehículo. Cada entrada captura varios aspectos del uso de vehículos eléctricos, lo que permite realizar análisis detallados y modelos predictivo>

# %% [markdown]
# ## Metodología base para la implementación de modelos de regresión logística o clasificación
# - **1.** Cargar, estructurar, depurar y preparar los datos de entrenamiento usando técnicas de análisis y filtrado de características
#     - Identificación y limpieza de datos irrelevantes
#     - Amputación, análisis de prioridad, transformación y normalización del conjunto.
#     - División de datos de entrenamiento y prueba (HOLD OUT)
# - **2.** Identificación y formulación de modelos
#     - Definición del modelo e hiperparametros de inicio
#     - Alimentación del modelo con datos de entrenamiento
#     - Predicción del modelo frente a datos Nuevos
#     - Ajuste de hiperparametros
# - **3.** Evaluación y métricas de desempeño para el ajuste
#     - Identificación de sobre ajuste y sub ajuste con métricas de precisión entre los segmentos de datos
#     - Validación cruzada
#     - Reporte de clasificación (Accuracy,Recall,Precision,F1-Score,support)
#     - Matriz de confusión
# - **4.** Análisis y visualización de tendencias
#     - Grafico de profundidad de arbol (max_depth: decision tree o random forest)
#     - Grafico de tendencia ROC Y Área bajo la curva (AUC)
#
#
#
# ## Conceptualización base
#
# *MODELOS DE CLASIFICACIÓN*
# - Regresión Logística: modelo de aprendizaje supervisado utilizado para resolver problemas de clasificación, especialmente binaria. utiliza la función Sigmoide para a convertir las predicciones. su salida es binaria de **clase 1 = 1 si la probabilidad >= 0.5** o **clase 0 = 0 si la probabilidad < 0.5**
#
# *MODELO BASADO EN ARBOLES DE DESICIÓN*
# - se utiliza tanto para problemas de clasificación como de regresión. Es fácil de interpretar y visualiza cómo el modelo toma decisiones. Un modelo basado en toma de decisiones por medio de reglas que define su propagabilidad por la probabilidad y la entropía de los datos. Salida de clasificación o regresión devolviendo la clase más frecuente o el promedio de las hojas.
#
# *NEIVE BAYES*
# - basado en el Teorema de Bayes y es utilizado principalmente para problemas de clasificación. Su característica principal es la suposición de independencia condicional entre las características. Calcula las probabilidades de que una muestra pertenezca a cada clase (0 o 1). Luego, asigna la clase con la probabilidad más alta como la predicción final. si su salida es 0.75, asigna un 1.
#     - Gaussiano: Para datos continuos, asume que las características siguen una distribución normal.
#     - Multinomial: Ideal para datos discretos, como conteos (e.g., palabras en texto).
#     - Bernoulli: Trabaja con variables binarias (e.g., presencia o ausencia de una palabra)
#
# *MAQUINAS DE SOPORTE VECTORIAL*
# - Su objetivo es encontrar un hiperplano que separe las clases de datos de la manera más clara posible, maximizando el margen entre las clases.
# Una vez entrenado, el modelo predice la clase de los nuevos puntos de datos basándose en qué lado del hiperplano se encuentran. Es muy efectivo en clasificación binaria y puede extenderse a problemas multi clase mediante técnicas como One-vs-One o One-vs-All.
# El modelo devuelve las clases predichas para cada observación, 0 o 1
#
#
#
# ## Evaluación y desempeño
# - Sobre ajuste y sub ajuste:
#
# Se evalúan los 4 conjuntos de datos que se segmentaron en el inicio, con el fin de identificar la exactitud de la respuesta en el orden de 0 a 1, y validar el desempeño del modelo frente a los datos nuevos. se entrena con los datos de entrenamiento y se compara con los mismos para identificar si responde bien a los datos estudiados, así mismo se vuelve y se evalúa con los datos de prueba y se compara con los mismos. Si la exactitud o rendimiento con los datos ya estudiados es mayor a los datos nuevos, se considera que el modelo esta sobre ajustado, es decir no generaliza eventos nuevos. si el rendimiento es bajo, tanto para datos ya estudiados como para los nuevos, el modelo tiene un subajuste que habrá que tratar con:
#
#     - Ajuste de hiperparametros
#     - Aumento de cantidad y calidad de los datos de entrenamiento
#     - Aumento del tiempo de entrenamiento
#
# -  Validación Cruzada:
#
# una técnica utilizada para evaluar el rendimiento de un modelo de aprendizaje automático y garantizar que no haya sobreajuste (overfitting) o subajuste (underfitting) al conjunto de datos de entrenamiento. La validación cruzada divide el conjunto de datos en varias partes y entrena el modelo varias veces, utilizando una de estas partes como conjunto de prueba (test) y las demás como conjunto de entrenamiento (train). Esto se repite para cada una de las partes. Al final, el rendimiento del modelo se promedia a lo largo de todas las iteraciones, lo que proporciona una estimación más robusta y generalizada del desempeño. el resultado de validación puede ser similar a la técnica de sub ajuste y sobre ajuste manual.
#
# - Reporte de clasificación:
#
# proporciona un informe detallado sobre el rendimiento de un modelo de clasificación:
#
# **Precisión (Precisión):**
# Indica la exactitud de las predicciones positivas (CLASE 1). Es decir, de todas las veces que el modelo predijo una clase positiva, cuántas fueron correctas.
# Interpretación: Alta precisión significa que las predicciones positivas son correctas en su mayoría.
#
# **Recall (Sensibilidad o Exhaustividad):**
# Mide cuántas veces el modelo identificó correctamente las muestras positivas. Es decir, de todas las instancias que eran realmente positivas, cuántas fueron predichas correctamente.
# Interpretación: Un alto recall significa que el modelo es muy bueno detectando la clase positiva, aunque pueda haber cometido más falsos positivos.
#
# **F1-Score:**
# Es la media armónica de la precisión y el recall. Se usa cuando se necesita un equilibrio entre ambas métricas.
# Interpretación: Un buen F1-score indica que el modelo tiene un buen balance entre precisión y recall.
#
# **Support:**
# El número de instancias reales de cada clase en el conjunto de prueba.
# Interpretación: Muestra cuántas observaciones pertenecen a cada clase.
#
# - Matriz de confusión:
#
# Esta matriz proporciona una representación visual y cuantitativa de los resultados de clasificación, comparando las predicciones del modelo con los valores reales (o verdaderos).
#
# a. True Positives (TP): Casos que el modelo predijo correctamente como positivos. Son los casos en los que el modelo acertó al predecir la clase positiva.
#
# b. True Negatives (TN): Casos que el modelo predijo correctamente como negativos. Son los casos en los que el modelo acertó al predecir la clase negativa.
#
# c. False Positives (FP): Casos que el modelo predijo incorrectamente como positivos, pero en realidad eran negativos. También conocidos como errores tipo I.
#
# d. False Negatives (FN): Casos que el modelo predijo incorrectamente como negativos, pero en realidad eran positivos. También conocidos como errores tipo II.
#
#
# ## Análisis y visualización de tendencia de rendimiento
#
#
#
# - **Curva ROC:**
#
# La Curva ROC es una representación gráfica que ilustra el rendimiento de un clasificador binario.
# En el eje Y, se encuentra el True Positive Rate (TPR), también conocido como Recall, que mide cuántos casos positivos fueron identificados correctamente. En el eje X, se encuentra el False Positive Rate (FPR), que mide cuántos casos negativos fueron incorrectamente clasificados como positivos
# Una gráfica ideal sería la que termina en la parte superior izquierda, donde el recall es alto y al FPR es bajo.
#
# - **AUC (Area Under the Curve):**
#
# AUC = 1: Modelo perfecto (sin errores).
# AUC = 0.5: Modelo aleatorio, sin capacidad de clasificación.
# AUC < 0.5: Modelo peor que aleatorio (lo que indicaría que el modelo tiene que ser corregido).

# %% [markdown]
# ## MONTAJE Y LIMPIEZA DE DATOS

# %% [markdown]
# ## Identificación de datos irrelevantes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("electric_cars.csv")
data = pd.DataFrame(data)
relevante = ['Battery Capacity (kWh)','Energy Consumed (kWh)','Charging Duration (hours)','Charging Rate (kW)','Time of Day','Day of Week','State of Charge (Start %)','State of Charge (End %)','Distance Driven (since last charge) (km)','Temperature (°C)','Vehicle Age (years)','Vehicle Model','User Type']

data= data[relevante]
data = data[data['User Type'].isin(['Commuter','Long-Distance Traveler'])]
data.head()

# %% [markdown]
# ## Análisis de la tipología

# %%
print(data.dtypes)
data['Vehicle Model'].unique()
# Out:
# Battery Capacity (kWh)                      float64
# Energy Consumed (kWh)                       float64
# Charging Duration (hours)                   float64
# Charging Rate (kW)                          float64
# Time of Day                                  object
# Day of Week                                  object
# State of Charge (Start %)                   float64
# State of Charge (End %)                     float64
# Distance Driven (since last charge) (km)    float64
# Temperature (°C)                            float64
# Vehicle Age (years)                         float64
# Vehicle Model                                object
# User Type                                    object
# dtype: object
# array(['BMW i3', 'Chevy Bolt', 'Hyundai Kona', 'Nissan Leaf',
#        'Tesla Model 3'], dtype=object)

# %% [markdown]
# ## Detección y manejo de datos faltantes

# %%
data.dropna(inplace=True)
data.drop_duplicates(inplace=True)
print(data.isnull().sum())
print(data.info())
# Out:
# Battery Capacity (kWh)                      0
# Energy Consumed (kWh)                       0
# Charging Duration (hours)                   0
# Charging Rate (kW)                          0
# Time of Day                                 0
# Day of Week                                 0
# State of Charge (Start %)                   0
# State of Charge (End %)                     0
# Distance Driven (since last charge) (km)    0
# Temperature (°C)                            0
# Vehicle Age (years)                         0
# Vehicle Model                               0
# User Type                                   0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 785 entries, 0 to 1319
# Data columns (total 13 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Battery Capacity (kWh)                    785 non-null    float64
# ...

# %% [markdown]
# ## Categorizar caracteristicas

# %%
data['User Type'].replace({'Commuter':1,'Long-Distance Traveler':0},inplace=True)
data['Time of Day'].replace({'Morning':1,'Evening':2,'Afternoon':3,'Night':4},inplace=True)
data['Day of Week'].replace({'Tuesday':2,'Thursday':4, 'Saturday':6, 'Friday':5, 'Monday':1, 'Wednesday':3,'Sunday':7},inplace=True)    
data['Vehicle Model'].replace({'BMW i3':1, 'Chevy Bolt':2, 'Hyundai Kona':3, 'Nissan Leaf':4,'Tesla Model 3':5},inplace=True)
data
# Out:
#       Battery Capacity (kWh)  Energy Consumed (kWh)  \
# 0                 108.463007              60.712346
# 2                  75.000000              19.128876
# 3                  50.000000              79.457824
# 4                  50.000000              19.629104
# 5                  50.000000              43.181137
# ...                      ...                    ...
# 1314               50.000000              43.251453
# 1315              100.000000              42.011654
# 1317              100.000000              18.895102
# 1318               85.000000              13.756252
# 1319              120.447195              63.652570
#
#       Charging Duration (hours)  Charging Rate (kW)  Time of Day  Day of Week  \
# 0                      0.591363           36.389181            2            2
# 2                      2.452653           27.513593            1            4
# 3                      1.266431           32.882870            2            6
# ...

# %%
data = (data-data.min())/(data.max()-data.min())
data.head()
# Out:
#    Battery Capacity (kWh)  Energy Consumed (kWh)  Charging Duration (hours)  \
# 0                0.571498               0.398616                   0.066034
# 2                0.392646               0.125388                   0.347246
# 3                0.259027               0.521785                   0.168026
# 4                0.259027               0.128674                   0.281844
# 5                0.259027               0.283425                   0.153100
#
#    Charging Rate (kW)  Time of Day  Day of Week  State of Charge (Start %)  \
# 0            0.364209     0.333333     0.166667                   0.219324
# 2            0.271630     0.000000     0.500000                   0.035671
# 3            0.327636     0.333333     0.833333                   0.657707
# 4            0.091198     0.000000     0.833333                   0.422310
# 5            0.134161     0.333333     0.833333                   0.593254
#
# ...

# %% [markdown]
# ## Divición en conjuntos de datos (HOLD OUT)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, RocCurveDisplay
from sklearn.linear_model import LogisticRegression

ind= ['Battery Capacity (kWh)','Energy Consumed (kWh)','Charging Duration (hours)','Charging Rate (kW)','Time of Day','Day of Week','State of Charge (Start %)','State of Charge (End %)','Distance Driven (since last charge) (km)','Temperature (°C)','Vehicle Age (years)','Vehicle Model']
x= data[ind]
y=data['User Type']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %% [markdown]
# # APLICACIÓN DE MODELOS DE CLASIFICACIÓN

# %% [markdown]
# ## _MODELO DE REGRESIÓN LOGÍSTICA_

# %%
model = LogisticRegression(random_state=1, max_iter=1000)

### AJUSTE DE HIPERPARAMETROS ###

model = LogisticRegression(
    random_state=1,
    C=1.0,               # Regularización estándar
    penalty='l2',        # Regularización L2
    solver='lbfgs',      # Optimizador predeterminado
    max_iter=1000        # Asegurarse de que converge
)

model.fit(x_train, y_train)
prediccion = model.predict(x_test)

### VALIDACIÓN DE SUB Y SOBRE AJUSTE  ###


y_train_pred = model.predict(x_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Train Accuracy:", train_accuracy)

y_test_pred = model.predict(x_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)

### VALIDACIÓN CRUZADA ###

cv_scores = cross_val_score(model, x, y, cv=5, scoring='accuracy')
print("CV Accuracy: ", cv_scores.mean())

### EVALUACIÓN ###

print("Classification Report:\n", classification_report(y_test, prediccion))
print("Confusion Matrix:\n", confusion_matrix(y_test, prediccion))
# Out:
# Train Accuracy: 0.5812101910828026
# Test Accuracy: 0.5031847133757962
# CV Accuracy:  0.5019108280254777
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.51      0.34      0.41        79
#          1.0       0.50      0.67      0.57        78
#
#     accuracy                           0.50       157
#    macro avg       0.50      0.50      0.49       157
# weighted avg       0.50      0.50      0.49       157
#
# Confusion Matrix:
#  [[27 52]
#  [26 52]]

# %% [markdown]
# ## _ARBOL DE DECISIÓN_

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

model = DecisionTreeClassifier(criterion='entropy', max_depth=20, random_state=1)

### AJUSTE DE HIPERPARAMETROS ###

model = DecisionTreeClassifier(
    criterion='entropy',     # Criterio de división ('gini' o 'entropy')
    max_depth=20,       # Profundidad máxima del árbol (ajustable)
    random_state=1       # Semilla para reproducibilidad
)

model.fit(x_train, y_train)
prediccion = model.predict(x_test)


### VALIDACION DE SUB Y SOBRE AJUSTE  ###


y_train_pred = model.predict(x_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Train Accuracy:", train_accuracy)

y_test_pred = model.predict(x_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)

### VALIDACIÓN CRUZADA ###

cv_scores = cross_val_score(model, x, y, cv=5, scoring='accuracy')
print("CV Accuracy: ", cv_scores.mean())

### EVALUACIÓN ###

print("Classification Report:\n", classification_report(y_test, prediccion))
print("Confusion Matrix:\n", confusion_matrix(y_test, prediccion))

### GRAFICO DE PROFUNDIDAD ###

plt.figure(figsize=(20, 10))
plot_tree(model, feature_names=x.columns, class_names=["Clase 0", "Clase 1"], filled=True)
plt.show()
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.4968152866242038
# CV Accuracy:  0.5121019108280255
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.50      0.42      0.46        79
#          1.0       0.49      0.58      0.53        78
#
#     accuracy                           0.50       157
#    macro avg       0.50      0.50      0.49       157
# weighted avg       0.50      0.50      0.49       157
#
# Confusion Matrix:
#  [[33 46]
#  [33 45]]

# %% [markdown]
# ## _MAQUINAS DE SOPORTE VECTORIAL_

# %%
from sklearn.svm import SVC

model = SVC(kernel='rbf',C=1.0,random_state=1)
model.fit(x_train, y_train)
prediccion = model.predict(x_test)

### VALIDACIÓN DE SUB Y SOBRE AJUSTE  ###


y_train_pred = model.predict(x_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Train Accuracy:", train_accuracy)

y_test_pred = model.predict(x_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)

### VALIDACIÓN CRUZADA ###

cv_scores = cross_val_score(model, x, y, cv=5, scoring='accuracy')
print("CV Accuracy: ", cv_scores.mean())


### EVALUACIÓN ###

print("Classification Report:\n", classification_report(y_test, prediccion))
print("Confusion Matrix:\n", confusion_matrix(y_test, prediccion))
# Out:
# Train Accuracy: 0.7133757961783439
# Test Accuracy: 0.5222929936305732
# CV Accuracy:  0.5273885350318472
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.54      0.37      0.44        79
#          1.0       0.51      0.68      0.59        78
#
#     accuracy                           0.52       157
#    macro avg       0.53      0.52      0.51       157
# weighted avg       0.53      0.52      0.51       157
#
# Confusion Matrix:
#  [[29 50]
#  [25 53]]

# %% [markdown]
# ## _NAIVE BAYES_

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

model = GaussianNB()
model.fit(x_train, y_train)
prediccion = model.predict(x_test)


### VALIDACIÓN DE SUB Y SOBRE AJUSTE  ###

y_train_pred = model.predict(x_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Train Accuracy:", train_accuracy)

y_test_pred = model.predict(x_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)

### VALIDACIÓN CRUZADA ###

cv_scores = cross_val_score(model, x, y, cv=5, scoring='accuracy')
print("CV Accuracy: ", cv_scores.mean())

### EVALUACIÓN ###

print("Classification Report:\n", classification_report(y_test, prediccion))
print("Confusion Matrix:\n", confusion_matrix(y_test, prediccion))
# Out:
# Train Accuracy: 0.5939490445859873
# Test Accuracy: 0.5414012738853503
# CV Accuracy:  0.49554140127388535
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.57      0.35      0.44        79
#          1.0       0.53      0.73      0.61        78
#
#     accuracy                           0.54       157
#    macro avg       0.55      0.54      0.53       157
# weighted avg       0.55      0.54      0.52       157
#
# Confusion Matrix:
#  [[28 51]
#  [21 57]]

# %% [markdown]
# # EVALUACIÓN Y METRICAS DE DESEMPEÑO

# %% [markdown]
# # _REPORTE DE CLASIFICACIÓN_
# Rendimiento del modelo en cada clase:
#
# ## Clase 0.0 (negativa)
#
# **Precisión (0.51):**
#
# Proporción de predicciones correctas para la clase 0 entre todas las predicciones hechas para la clase 0.
# De todas las veces que el modelo predijo 0, acertó el 51%.
#
# **Recall (0.34):**
#
# Proporción de instancias de la clase 0 correctamente identificadas.
# De todas las instancias verdaderas de la clase 0, el modelo capturó el 34%.
#
# **F1-Score (0.41):**
#
# Promedio armónico de precision y recall, útil cuando hay desbalance entre clases.
# Resultado bajo porque el modelo tiene un recall pobre para esta clase.
#
# ## Clase 1.0 (positiva):
#
# **Precisión (0.50):**
#
# De todas las predicciones hechas como clase 1, el modelo acertó el 50%.
#
# **Recall (0.67):**
#
# De todas las instancias verdaderas de la clase 1, el modelo identificó correctamente el 67%.
#
# **F1-Score (0.57):**
#
# Mejor que para la clase 0 porque el modelo tiene mayor recall para esta clase.

# %% [markdown]
# # _MATRIZ DE CONFUSIÓN_

# %% [raw]
# ____|___|Predicción: 1 (Positivo) | Predicción: 0 (Negativo)|
# Real| 1 |   True Positive (TP)    |   False Negative (FN)   |
# Real| 0 |   False Positive (FP)   |	  True Negative (TN)    |
#
#
# Precisión del 50%, baja precisión, sugiere que el modelo gestiona lo mismo que adivinar al azar
# La precisión para ambas clases es similar (alrededor de 50%), lo que indica que el modelo no está sesgado hacia una clase.

# %% [markdown]
# # _Curva ROC y AUC_

# %%
from sklearn.metrics import roc_curve, auc, RocCurveDisplay
import matplotlib.pyplot as plt

y_proba = model.predict_proba(x_test)[:, 1] ## predice la probabilidad y no la clase, si es requerido

fpr, tpr, thresholds = roc_curve(y_test, y_proba)

# Calcular el área bajo la curva (AUC)
roc_auc = auc(fpr, tpr)
print("AUC:", roc_auc)


RocCurveDisplay.from_predictions(y_test, y_proba)

plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2)  # Línea diagonal
plt.title("ROC Curve")
plt.show()
# Out:
# AUC: 0.5577734501785135

# %% [markdown]
# La recta con pendiente en 1, se utiliza para dividir el grafico en dos partes, para interpretar la delimitación mínima de cota para la curva dada por el RECALL y el FPR, esto sugiere que debajo de la línea recta, el sistema para la predicción de la clase positiva no es eficiente, si el área bajo esa curva aumenta determina que el rendimiento del modelo aumento en términos del TPR o Recall versus a un FPR.
